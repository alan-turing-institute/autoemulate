# %%
# %load_ext autoreload 
# %autoreload 2

import os
os.chdir("/Users/mbalmus/Desktop/Projects/Git/autoemulate-tutorial/utils/")

# !pwd
# Out:
# /Users/mbalmus/Desktop/Projects/Git/autoemulate-tutorial/utils

# %%
from flow_functions import FlowProblem

# %%
fp = FlowProblem(ncycles=20, amp=900.)

# %%
fp.generate_pulse_function()

# %%
fp.solve()

# %%
fp.res.t
# Out:
# array([19.00046485, 19.00146485, 19.00246485, ..., 19.99846485,
#        19.99946485, 20.        ])

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = fp.plot_res()
plt.show()
